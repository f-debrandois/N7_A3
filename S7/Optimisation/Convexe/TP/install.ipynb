# %%
# activate local project
using Pkg
Pkg.activate(".")
# Out:
#   Activating new project at `~/Cours/S7/Optimisation/Convexe/TP`

# %%
# install the packages in the local project
Pkg.add("Images")
Pkg.add("Colors")
Pkg.add("LinearAlgebra")
Pkg.add("FFTW")
Pkg.add("Plots")
# Out:
#    Resolving package versions...
#     Updating `~/Cours/S7/Optimisation/Convexe/TP/Project.toml`
#   [916415d5] + Images v0.26.0
#     Updating `~/Cours/S7/Optimisation/Convexe/TP/Manifest.toml`
#   [621f4979] + AbstractFFTs v1.5.0
#   [79e6a3ab] + Adapt v4.0.0
#   [ec485272] + ArnoldiMethod v0.2.0
#   [4fba245c] + ArrayInterface v7.7.0
#   [13072b0f] + AxisAlgorithms v1.1.0
#   [39de3d68] + AxisArrays v0.4.7
#   [62783981] + BitTwiddlingConvenienceFunctions v0.1.5
#   [fa961155] + CEnum v0.5.0
#   [2a0fbf3d] + CPUSummary v0.2.4
#   [aafaddc9] + CatIndices v0.2.2
#   [d360d2e6] + ChainRulesCore v1.19.1
#   [fb6a15b2] + CloseOpenIntervals v0.1.12
#   [aaaa29a8] + Clustering v0.15.6
#   [35d6a980] + ColorSchemes v3.24.0
#   [3da002f7] + ColorTypes v0.11.4
#   [c3611d14] + ColorVectorSpace v0.10.0
#   [5ae59095] + Colors v0.12.10
#   [34da2185] + Compat v4.12.0
#   [ed09eef8] + ComputationalResources v0.3.2
#   [150eb455] + CoordinateTransformations v0.6.3
# ...
