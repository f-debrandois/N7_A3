# %% [markdown]
# # Préambule
#
# On se propose dans ce TP d'illustrer certains techniques **d'apprentissage semi-supervisé** vues en cours.
#
# Dans tout ce qui suit, on considère que l'on dispose d'un ensemble de données $x_{lab}$ labellisées et d'un ensemble de donnés $x_{unlab}$ non labellisées.

# %% [markdown]
# ## Datasets

# %% [markdown]
# Commencez par exécuter ces codes qui vos permettront de charger les datasets que nous allons utiliser et de les partager en données labellisées et non labellisées, ainsi qu'en données de test.

# %% [markdown]
# ### Dataset des deux clusters

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import datasets
import matplotlib.pyplot as plt

def generate_2clusters_dataset(num_lab = 10, num_unlab=740, num_test=250):
  num_samples = num_lab + num_unlab + num_test
  # Génération de 1000 données du dataset des 2 lunes
  x, y = datasets.make_blobs(n_samples=[round(num_samples/2), round(num_samples/2)], n_features=2, center_box=(- 3, 3), random_state=1)

  x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=num_test/num_samples, random_state=1)
  x_train_lab, x_train_unlab, y_train_lab, y_train_unlab = train_test_split(x_train, y_train, test_size=num_unlab/(num_unlab+num_lab), random_state=6)

  return x_train_lab, y_train_lab, x_train_unlab, y_train_unlab, x_test, y_test

# %%
x_train_lab, y_train_lab, x_train_unlab, y_train_unlab, x_test, y_test = generate_2clusters_dataset(num_lab = 10, num_unlab=740, num_test=250)

print(x_train_lab.shape, x_train_unlab.shape, x_test.shape)
print(y_train_lab.shape, y_train_unlab.shape, y_test.shape)

# Affichage des données
plt.plot(x_train_unlab[y_train_unlab==0,0], x_train_unlab[y_train_unlab==0,1], 'b.')
plt.plot(x_train_unlab[y_train_unlab==1,0], x_train_unlab[y_train_unlab==1,1], 'r.')

plt.plot(x_test[y_test==0,0], x_test[y_test==0,1], 'b+')
plt.plot(x_test[y_test==1,0], x_test[y_test==1,1], 'r+')

plt.plot(x_train_lab[y_train_lab==0,0], x_train_lab[y_train_lab==0,1], 'b.', markersize=30)
plt.plot(x_train_lab[y_train_lab==1,0], x_train_lab[y_train_lab==1,1], 'r.', markersize=30)

plt.show()
# Out:
# (10, 2) (740, 2) (250, 2)
# (10,) (740,) (250,)

# %% [markdown]
# ### Dataset des 2 lunes

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1xb_gasBJ6sEmbyvCWTnVEAsbspyDCyFL">
# <caption><center> Figure 1: Comparaison de différents algorithmes semi-supervisés sur le dataset des 2 lunes</center></caption>

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import datasets
import matplotlib.pyplot as plt

def generate_2moons_dataset(num_lab = 10, num_unlab=740, num_test=250):
  num_samples = num_lab + num_unlab + num_test
  # Génération de 1000 données du dataset des 2 lunes
  x, y = datasets.make_moons(n_samples=num_samples, noise=0.1, random_state=1)

  x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=num_test/num_samples, random_state=1)
  x_train_lab, x_train_unlab, y_train_lab, y_train_unlab = train_test_split(x_train, y_train, test_size=num_unlab/(num_unlab+num_lab), random_state=6)

  return x_train_lab, y_train_lab, x_train_unlab, y_train_unlab, x_test, y_test

# %%
x_train_lab, y_train_lab, x_train_unlab, y_train_unlab, x_test, y_test = generate_2moons_dataset(num_lab = 10, num_unlab=740, num_test=250)

print(x_train_lab.shape, x_train_unlab.shape, x_test.shape)
print(y_train_lab.shape, y_train_unlab.shape, y_test.shape)

# Affichage des données
plt.plot(x_train_unlab[y_train_unlab==0,0], x_train_unlab[y_train_unlab==0,1], 'b.')
plt.plot(x_train_unlab[y_train_unlab==1,0], x_train_unlab[y_train_unlab==1,1], 'r.')

plt.plot(x_test[y_test==0,0], x_test[y_test==0,1], 'b+')
plt.plot(x_test[y_test==1,0], x_test[y_test==1,1], 'r+')

plt.plot(x_train_lab[y_train_lab==0,0], x_train_lab[y_train_lab==0,1], 'b.', markersize=30)
plt.plot(x_train_lab[y_train_lab==1,0], x_train_lab[y_train_lab==1,1], 'r.', markersize=30)

plt.show()
# Out:
# (10, 2) (740, 2) (250, 2)
# (10,) (740,) (250,)

# %% [markdown]
# ### MNIST

# %%
from tensorflow.keras.datasets import mnist
import numpy as np
from sklearn.model_selection import train_test_split

def generate_mnist_dataset(num_lab = 10):

  # Chargement et normalisation (entre 0 et 1) des données de la base de données MNIST
  (x_train, y_train), (x_test, y_test) = mnist.load_data()

  x_train = np.expand_dims(x_train.astype('float32') / 255., 3)
  x_test = np.expand_dims(x_test.astype('float32') / 255., 3)

  x_train_lab, x_train_unlab, y_train_lab, y_train_unlab = train_test_split(x_train, y_train, test_size=(x_train.shape[0]-num_lab)/x_train.shape[0], random_state=2)

  return x_train_lab, y_train_lab, x_train_unlab, y_train_unlab, x_test, y_test
# Out:
# 2024-10-04 09:58:13.224164: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-10-04 09:58:13.228965: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-10-04 09:58:13.279172: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-04 09:58:13.279220: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-04 09:58:13.279270: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-04 09:58:13.289215: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-10-04 09:58:13.289969: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-04 09:58:14.217397: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
x_train_lab, y_train_lab, x_train_unlab, y_train_unlab, x_test, y_test = generate_mnist_dataset(num_lab = 10)

print(x_train_lab.shape, x_train_unlab.shape, x_test.shape)
print(y_train_lab.shape, y_train_unlab.shape, y_test.shape)
# Out:
# (10, 28, 28, 1) (59990, 28, 28, 1) (10000, 28, 28, 1)
# (10,) (59990,) (10000,)

# %% [markdown]
# ## Modèles

# %% [markdown]
# Nous allons dès maintenant préparer les modèles que nous utiliserons dans la suite, à vous de les compléter :

# %%
from tensorflow.keras.layers import *
from tensorflow.keras import Model, Input
# A COMPLETER
# Ici, écrire un simple perceptron monocouche
def create_model_2clusters():

  inputs = Input(shape=(2,))

  outputs = Dense(1, activation='sigmoid')(inputs)

  model = Model(inputs=inputs, outputs=outputs)

  return model

# %%
# A COMPLETER
# Ici, écrire un perceptron multi-couches à une seule couche cachée comprenant 20 neurones
def create_model_2moons():

  inputs = keras.Input(shape=(2,))
  x = Dense(20, activation='relu')(inputs)

  outputs = Dense(1, activation='sigmoid')(x)
  
  model = keras.Model(inputs=inputs, outputs=outputs)

  return model

# %%
# A COMPLETER
# Ici, on implémentera le modèle LeNet-5 :
# 1 couche de convolution 5x5 à 6 filtres suivie d'un max pooling
# puis 1 couche de convolution 5x5 à 16 filtres suivie d'un max pooling et d'un Flatten
# Enfin 2 couches denses de 120 et 84 neurones, avant la couche de sortie à 10 neurones.
def create_model_mnist():

  inputs = keras.Input(shape=(28, 28, 1))
  x = Conv2D(6, kernel_size=(5, 5), activation='relu')(inputs)
  x = MaxPooling2D(pool_size=(2, 2))(x)
  x = Conv2D(16, kernel_size=(5, 5), activation='relu')(x)
  x = MaxPooling2D(pool_size=(2, 2))(x)
  x = Flatten()(x)
  x = Dense(120, activation='relu')(x)
  x = Dense(84, activation='relu')(x)

  outputs = Dense(10, activation='softmax')(x)

  model = keras.Model(inputs=inputs, outputs=outputs)

  return model

# %% [markdown]
# # Apprentissage supervisé

# %% [markdown]
# Commencez par bien lire le code ci-dessous, qui vous permet de mettre en place un apprentissage supervisé en détaillant la boucle d'apprentissage. Cela nous permettra d'avoir plus de contrôle dans la suite pour implémenter les algorithmes semi-supervisés.
#
# Cela vous fournira également une base contre laquelle comparer les algorithmes semi-supervisés.

# %% [markdown]
# ### Dataset des 2 clusters

# %%
import tensorflow as tf
from tensorflow import keras
import math

# Données et modèle du problème des 2 clusters
x_train_lab, y_train_lab, x_train_unlab, y_train_unlab, x_test, y_test = generate_2clusters_dataset(num_lab = 10, num_unlab=740, num_test=250)
model = create_model_2clusters()

# Hyperparamètres de l'apprentissage
epochs = 150
batch_size = 16
if batch_size < x_train_lab.shape[0]:
  steps_per_epoch = math.floor(x_train_lab.shape[0]/batch_size)
else:
  steps_per_epoch = 1
  batch_size = x_train_lab.shape[0]

# Instanciation d'un optimiseur et d'une fonction de coût.
optimizer = keras.optimizers.Adam(learning_rate=1e-2)
loss_fn = keras.losses.BinaryCrossentropy()

# Préparation des métriques pour le suivi de la performance du modèle.
train_acc_metric = keras.metrics.BinaryAccuracy()
test_acc_metric = keras.metrics.BinaryAccuracy()

# Indices de l'ensemble labellisé
indices = np.arange(x_train_lab.shape[0])

# Boucle sur les epochs
for epoch in range(epochs):

  # A chaque nouvelle epoch, on randomise les indices de l'ensemble labellisé
  np.random.shuffle(indices)

  # Et on recommence à cumuler la loss
  cum_loss_value = 0

  for step in range(steps_per_epoch):

    # Sélection des données du prochain batch
    x_batch = x_train_lab[indices[step*batch_size: (step+1)*batch_size]]
    y_batch = y_train_lab[indices[step*batch_size: (step+1)*batch_size]]

    # Etape nécessaire pour comparer y_batch à la sortie du réseau
    y_batch = np.expand_dims(y_batch, 1)

    # Les opérations effectuées par le modèle dans ce bloc sont suivies et permettront
    # la différentiation automatique.
    with tf.GradientTape() as tape:

      # Application du réseau aux données d'entrée
      y_pred = model(x_batch, training=True)  # Logits for this minibatch

      # Calcul de la fonction de perte sur ce batch
      loss_value = loss_fn(y_batch, y_pred)

      # Calcul des gradients par différentiation automatique
      grads = tape.gradient(loss_value, model.trainable_weights)

      # Réalisation d'une itération de la descente de gradient (mise à jour des paramètres du réseau)
      optimizer.apply_gradients(zip(grads, model.trainable_weights))

      # Mise à jour de la métrique
      train_acc_metric.update_state(y_batch, y_pred)

      cum_loss_value = cum_loss_value + loss_value

  # Calcul de la précision à la fin de l'epoch
  train_acc = train_acc_metric.result()

  # Calcul de la précision sur l'ensemble de test à la fin de l'epoch
  test_logits = model(x_test, training=False)
  test_acc_metric.update_state(np.expand_dims(y_test, 1), test_logits)
  test_acc = test_acc_metric.result()

  print("Epoch %4d : Loss : %.4f, Acc : %.4f, Test Acc : %.4f" % (epoch, float(cum_loss_value/steps_per_epoch), float(train_acc), float(test_acc)))

  # Remise à zéro des métriques pour la prochaine epoch
  train_acc_metric.reset_state()
  test_acc_metric.reset_state()
# Out:
# Epoch    0 : Loss : 1.7877, Acc : 0.1000, Test Acc : 0.1680
# Epoch    1 : Loss : 1.7619, Acc : 0.1000, Test Acc : 0.1680
# Epoch    2 : Loss : 1.7363, Acc : 0.1000, Test Acc : 0.1680
# Epoch    3 : Loss : 1.7107, Acc : 0.1000, Test Acc : 0.1640
# Epoch    4 : Loss : 1.6853, Acc : 0.1000, Test Acc : 0.1600
# Epoch    5 : Loss : 1.6600, Acc : 0.1000, Test Acc : 0.1600
# Epoch    6 : Loss : 1.6349, Acc : 0.1000, Test Acc : 0.1560
# Epoch    7 : Loss : 1.6099, Acc : 0.1000, Test Acc : 0.1520
# Epoch    8 : Loss : 1.5850, Acc : 0.1000, Test Acc : 0.1480
# Epoch    9 : Loss : 1.5603, Acc : 0.1000, Test Acc : 0.1480
# Epoch   10 : Loss : 1.5358, Acc : 0.1000, Test Acc : 0.1480
# Epoch   11 : Loss : 1.5114, Acc : 0.1000, Test Acc : 0.1440
# Epoch   12 : Loss : 1.4873, Acc : 0.1000, Test Acc : 0.1440
# Epoch   13 : Loss : 1.4633, Acc : 0.1000, Test Acc : 0.1400
# Epoch   14 : Loss : 1.4395, Acc : 0.0000, Test Acc : 0.1360
# Epoch   15 : Loss : 1.4159, Acc : 0.0000, Test Acc : 0.1320
# Epoch   16 : Loss : 1.3926, Acc : 0.0000, Test Acc : 0.1320
# Epoch   17 : Loss : 1.3694, Acc : 0.0000, Test Acc : 0.1320
# Epoch   18 : Loss : 1.3465, Acc : 0.0000, Test Acc : 0.1320
# Epoch   19 : Loss : 1.3239, Acc : 0.0000, Test Acc : 0.1240
# Epoch   20 : Loss : 1.3015, Acc : 0.0000, Test Acc : 0.1200
# Epoch   21 : Loss : 1.2793, Acc : 0.0000, Test Acc : 0.1160
# Epoch   22 : Loss : 1.2574, Acc : 0.0000, Test Acc : 0.1160
# Epoch   23 : Loss : 1.2358, Acc : 0.0000, Test Acc : 0.1160
# Epoch   24 : Loss : 1.2145, Acc : 0.0000, Test Acc : 0.1120
# Epoch   25 : Loss : 1.1934, Acc : 0.0000, Test Acc : 0.1080
# Epoch   26 : Loss : 1.1727, Acc : 0.0000, Test Acc : 0.1080
# Epoch   27 : Loss : 1.1522, Acc : 0.0000, Test Acc : 0.1080
# Epoch   28 : Loss : 1.1321, Acc : 0.0000, Test Acc : 0.1080
# Epoch   29 : Loss : 1.1123, Acc : 0.0000, Test Acc : 0.1040
# Epoch   30 : Loss : 1.0928, Acc : 0.0000, Test Acc : 0.1040
# Epoch   31 : Loss : 1.0736, Acc : 0.0000, Test Acc : 0.1040
# Epoch   32 : Loss : 1.0548, Acc : 0.0000, Test Acc : 0.1040
# Epoch   33 : Loss : 1.0363, Acc : 0.0000, Test Acc : 0.1000
# Epoch   34 : Loss : 1.0181, Acc : 0.0000, Test Acc : 0.1000
# Epoch   35 : Loss : 1.0003, Acc : 0.0000, Test Acc : 0.1040
# Epoch   36 : Loss : 0.9828, Acc : 0.0000, Test Acc : 0.1040
# Epoch   37 : Loss : 0.9657, Acc : 0.0000, Test Acc : 0.1080
# Epoch   38 : Loss : 0.9489, Acc : 0.0000, Test Acc : 0.1080
# Epoch   39 : Loss : 0.9324, Acc : 0.0000, Test Acc : 0.1120
# Epoch   40 : Loss : 0.9163, Acc : 0.0000, Test Acc : 0.1200
# Epoch   41 : Loss : 0.9006, Acc : 0.0000, Test Acc : 0.1400
# Epoch   42 : Loss : 0.8852, Acc : 0.0000, Test Acc : 0.1560
# Epoch   43 : Loss : 0.8701, Acc : 0.0000, Test Acc : 0.1720
# Epoch   44 : Loss : 0.8554, Acc : 0.0000, Test Acc : 0.1800
# Epoch   45 : Loss : 0.8409, Acc : 0.0000, Test Acc : 0.2040
# Epoch   46 : Loss : 0.8269, Acc : 0.0000, Test Acc : 0.2240
# Epoch   47 : Loss : 0.8131, Acc : 0.0000, Test Acc : 0.2600
# Epoch   48 : Loss : 0.7997, Acc : 0.0000, Test Acc : 0.3000
# Epoch   49 : Loss : 0.7865, Acc : 0.0000, Test Acc : 0.3320
# Epoch   50 : Loss : 0.7737, Acc : 0.2000, Test Acc : 0.3800
# Epoch   51 : Loss : 0.7612, Acc : 0.2000, Test Acc : 0.4280
# Epoch   52 : Loss : 0.7489, Acc : 0.2000, Test Acc : 0.4760
# Epoch   53 : Loss : 0.7369, Acc : 0.3000, Test Acc : 0.5000
# Epoch  129 : Loss : 0.2989, Acc : 0.9000, Test Acc : 0.9560
# Epoch  130 : Loss : 0.2964, Acc : 0.9000, Test Acc : 0.9520
# Epoch  131 : Loss : 0.2940, Acc : 0.9000, Test Acc : 0.9520
# Epoch  132 : Loss : 0.2916, Acc : 0.9000, Test Acc : 0.9520
# Epoch  133 : Loss : 0.2893, Acc : 0.9000, Test Acc : 0.9520
# Epoch  134 : Loss : 0.2870, Acc : 1.0000, Test Acc : 0.9520
# Epoch  135 : Loss : 0.2847, Acc : 1.0000, Test Acc : 0.9520
# Epoch  136 : Loss : 0.2825, Acc : 1.0000, Test Acc : 0.9520
# Epoch  137 : Loss : 0.2803, Acc : 1.0000, Test Acc : 0.9520
# Epoch  138 : Loss : 0.2782, Acc : 1.0000, Test Acc : 0.9520
# Epoch  139 : Loss : 0.2761, Acc : 1.0000, Test Acc : 0.9520
# Epoch  140 : Loss : 0.2740, Acc : 1.0000, Test Acc : 0.9520
# Epoch  141 : Loss : 0.2719, Acc : 1.0000, Test Acc : 0.9480
# Epoch  142 : Loss : 0.2699, Acc : 1.0000, Test Acc : 0.9520
# Epoch  143 : Loss : 0.2679, Acc : 1.0000, Test Acc : 0.9520
# Epoch  144 : Loss : 0.2660, Acc : 1.0000, Test Acc : 0.9520
# Epoch  145 : Loss : 0.2640, Acc : 1.0000, Test Acc : 0.9520
# Epoch  146 : Loss : 0.2621, Acc : 1.0000, Test Acc : 0.9520
# Epoch  147 : Loss : 0.2603, Acc : 1.0000, Test Acc : 0.9520
# Epoch  148 : Loss : 0.2584, Acc : 1.0000, Test Acc : 0.9520
# Epoch  149 : Loss : 0.2566, Acc : 1.0000, Test Acc : 0.9520

# %%
from mlxtend.plotting import plot_decision_regions

# Affichage des données
plt.plot(x_train_unlab[y_train_unlab==0,0], x_train_unlab[y_train_unlab==0,1], 'b.')
plt.plot(x_train_unlab[y_train_unlab==1,0], x_train_unlab[y_train_unlab==1,1], 'r.')

plt.plot(x_test[y_test==0,0], x_test[y_test==0,1], 'b+')
plt.plot(x_test[y_test==1,0], x_test[y_test==1,1], 'r+')

plt.plot(x_train_lab[y_train_lab==0,0], x_train_lab[y_train_lab==0,1], 'b.', markersize=30)
plt.plot(x_train_lab[y_train_lab==1,0], x_train_lab[y_train_lab==1,1], 'r.', markersize=30)

plt.show()

#Affichage de la frontière de décision
plot_decision_regions(x_train_unlab, y_train_unlab, clf=model, legend=2)
plt.show()
# Out:
# 9600/9600 [==============================] - 16s 2ms/step

# %% [markdown]
# ### Dataset des 2 lunes

# %% [markdown]
# Remettez en place le même apprentissage pour le dataset des 2 lunes.

# %%
import tensorflow as tf
from tensorflow import keras
import math

# Données et modèle du problème des 2 clusters
x_train_lab, y_train_lab, x_train_unlab, y_train_unlab, x_test, y_test = generate_2moons_dataset(num_lab = 10, num_unlab=740, num_test=250)
model = create_model_2moons()

# Hyperparamètres de l'apprentissage
epochs = 150
batch_size = 16
if batch_size < x_train_lab.shape[0]:
  steps_per_epoch = math.floor(x_train_lab.shape[0]/batch_size)
else:
  steps_per_epoch = 1
  batch_size = x_train_lab.shape[0]

# Instanciation d'un optimiseur et d'une fonction de coût.
optimizer = keras.optimizers.Adam(learning_rate=1e-2)
loss_fn = keras.losses.BinaryCrossentropy()

# Préparation des métriques pour le suivi de la performance du modèle.
train_acc_metric = keras.metrics.BinaryAccuracy()
test_acc_metric = keras.metrics.BinaryAccuracy()

# Indices de l'ensemble labellisé
indices = np.arange(x_train_lab.shape[0])

# Boucle sur les epochs
for epoch in range(epochs):

  # A chaque nouvelle epoch, on randomise les indices de l'ensemble labellisé
  np.random.shuffle(indices)

  # Et on recommence à cumuler la loss
  cum_loss_value = 0

  for step in range(steps_per_epoch):

    # Sélection des données du prochain batch
    x_batch = x_train_lab[indices[step*batch_size: (step+1)*batch_size]]
    y_batch = y_train_lab[indices[step*batch_size: (step+1)*batch_size]]

    # Etape nécessaire pour comparer y_batch à la sortie du réseau
    y_batch = np.expand_dims(y_batch, 1)

    # Les opérations effectuées par le modèle dans ce bloc sont suivies et permettront
    # la différentiation automatique.
    with tf.GradientTape() as tape:

      # Application du réseau aux données d'entrée
      y_pred = model(x_batch, training=True)  # Logits for this minibatch

      # Calcul de la fonction de perte sur ce batch
      loss_value = loss_fn(y_batch, y_pred)

      # Calcul des gradients par différentiation automatique
      grads = tape.gradient(loss_value, model.trainable_weights)

      # Réalisation d'une itération de la descente de gradient (mise à jour des paramètres du réseau)
      optimizer.apply_gradients(zip(grads, model.trainable_weights))

      # Mise à jour de la métrique
      train_acc_metric.update_state(y_batch, y_pred)

      cum_loss_value = cum_loss_value + loss_value

  # Calcul de la précision à la fin de l'epoch
  train_acc = train_acc_metric.result()

  # Calcul de la précision sur l'ensemble de test à la fin de l'epoch
  test_logits = model(x_test, training=False)
  test_acc_metric.update_state(np.expand_dims(y_test, 1), test_logits)
  test_acc = test_acc_metric.result()

  print("Epoch %4d : Loss : %.4f, Acc : %.4f, Test Acc : %.4f" % (epoch, float(cum_loss_value/steps_per_epoch), float(train_acc), float(test_acc)))

  # Remise à zéro des métriques pour la prochaine epoch
  train_acc_metric.reset_state()
  test_acc_metric.reset_state()
# Out:
# Epoch    0 : Loss : 0.7245, Acc : 0.4000, Test Acc : 0.6320
# Epoch    1 : Loss : 0.6867, Acc : 0.7000, Test Acc : 0.7080
# Epoch    2 : Loss : 0.6514, Acc : 0.7000, Test Acc : 0.7720
# Epoch    3 : Loss : 0.6195, Acc : 0.9000, Test Acc : 0.8000
# Epoch    4 : Loss : 0.5909, Acc : 0.9000, Test Acc : 0.7720
# Epoch    5 : Loss : 0.5650, Acc : 0.9000, Test Acc : 0.7800
# Epoch    6 : Loss : 0.5415, Acc : 0.9000, Test Acc : 0.7840
# Epoch    7 : Loss : 0.5205, Acc : 0.9000, Test Acc : 0.8000
# Epoch    8 : Loss : 0.5024, Acc : 0.9000, Test Acc : 0.8120
# Epoch    9 : Loss : 0.4864, Acc : 0.9000, Test Acc : 0.8120
# Epoch   10 : Loss : 0.4722, Acc : 0.9000, Test Acc : 0.8080
# Epoch   11 : Loss : 0.4595, Acc : 0.9000, Test Acc : 0.8160
# Epoch   12 : Loss : 0.4480, Acc : 0.9000, Test Acc : 0.8240
# Epoch   13 : Loss : 0.4375, Acc : 0.9000, Test Acc : 0.8240
# Epoch   14 : Loss : 0.4277, Acc : 0.9000, Test Acc : 0.8320
# Epoch   15 : Loss : 0.4185, Acc : 0.9000, Test Acc : 0.8400
# Epoch   16 : Loss : 0.4096, Acc : 0.9000, Test Acc : 0.8360
# Epoch   17 : Loss : 0.4009, Acc : 0.9000, Test Acc : 0.8440
# Epoch   18 : Loss : 0.3924, Acc : 0.9000, Test Acc : 0.8480
# Epoch   19 : Loss : 0.3842, Acc : 0.9000, Test Acc : 0.8560
# Epoch   20 : Loss : 0.3762, Acc : 0.9000, Test Acc : 0.8600
# Epoch   21 : Loss : 0.3683, Acc : 0.9000, Test Acc : 0.8640
# Epoch   22 : Loss : 0.3607, Acc : 0.9000, Test Acc : 0.8640
# Epoch   23 : Loss : 0.3532, Acc : 0.9000, Test Acc : 0.8680
# Epoch   24 : Loss : 0.3459, Acc : 0.9000, Test Acc : 0.8760
# Epoch   25 : Loss : 0.3388, Acc : 0.9000, Test Acc : 0.8720
# Epoch   26 : Loss : 0.3317, Acc : 0.9000, Test Acc : 0.8720
# Epoch   27 : Loss : 0.3247, Acc : 0.9000, Test Acc : 0.8680
# Epoch   28 : Loss : 0.3180, Acc : 0.9000, Test Acc : 0.8600
# Epoch   29 : Loss : 0.3116, Acc : 0.9000, Test Acc : 0.8600
# Epoch   30 : Loss : 0.3055, Acc : 0.8000, Test Acc : 0.8640
# Epoch   31 : Loss : 0.2997, Acc : 0.8000, Test Acc : 0.8640
# Epoch   32 : Loss : 0.2942, Acc : 0.8000, Test Acc : 0.8600
# Epoch   33 : Loss : 0.2889, Acc : 0.8000, Test Acc : 0.8560
# Epoch   34 : Loss : 0.2840, Acc : 0.8000, Test Acc : 0.8560
# Epoch   35 : Loss : 0.2794, Acc : 0.8000, Test Acc : 0.8600
# Epoch   36 : Loss : 0.2750, Acc : 0.8000, Test Acc : 0.8680
# Epoch   37 : Loss : 0.2709, Acc : 0.8000, Test Acc : 0.8680
# Epoch   38 : Loss : 0.2670, Acc : 0.8000, Test Acc : 0.8720
# Epoch   39 : Loss : 0.2632, Acc : 0.8000, Test Acc : 0.8760
# Epoch   40 : Loss : 0.2595, Acc : 0.8000, Test Acc : 0.8760
# Epoch   41 : Loss : 0.2560, Acc : 0.8000, Test Acc : 0.8760
# Epoch   42 : Loss : 0.2525, Acc : 0.8000, Test Acc : 0.8760
# Epoch   43 : Loss : 0.2491, Acc : 0.8000, Test Acc : 0.8760
# Epoch   44 : Loss : 0.2458, Acc : 0.8000, Test Acc : 0.8760
# Epoch   45 : Loss : 0.2425, Acc : 0.8000, Test Acc : 0.8760
# Epoch   46 : Loss : 0.2394, Acc : 0.8000, Test Acc : 0.8800
# Epoch   47 : Loss : 0.2364, Acc : 0.8000, Test Acc : 0.8800
# Epoch   48 : Loss : 0.2334, Acc : 0.8000, Test Acc : 0.8840
# Epoch   49 : Loss : 0.2306, Acc : 0.8000, Test Acc : 0.8840
# Epoch   50 : Loss : 0.2277, Acc : 0.8000, Test Acc : 0.8840
# Epoch   51 : Loss : 0.2250, Acc : 0.8000, Test Acc : 0.8880
# Epoch   52 : Loss : 0.2223, Acc : 0.8000, Test Acc : 0.8920
# Epoch   53 : Loss : 0.2197, Acc : 0.8000, Test Acc : 0.9000
# Epoch   54 : Loss : 0.2172, Acc : 0.8000, Test Acc : 0.9000
# Epoch   55 : Loss : 0.2153, Acc : 0.8000, Test Acc : 0.9000
# Epoch   56 : Loss : 0.2133, Acc : 0.8000, Test Acc : 0.9000
# Epoch   57 : Loss : 0.2115, Acc : 0.8000, Test Acc : 0.9040
# Epoch   58 : Loss : 0.2096, Acc : 0.8000, Test Acc : 0.9040
# Epoch   59 : Loss : 0.2078, Acc : 0.8000, Test Acc : 0.9040
# Epoch   60 : Loss : 0.2062, Acc : 0.8000, Test Acc : 0.8960
# Epoch   61 : Loss : 0.2045, Acc : 0.8000, Test Acc : 0.8960
# Epoch   62 : Loss : 0.2029, Acc : 0.8000, Test Acc : 0.8880
# Epoch   63 : Loss : 0.2013, Acc : 0.8000, Test Acc : 0.8880
# Epoch   64 : Loss : 0.1998, Acc : 0.8000, Test Acc : 0.8880
# Epoch   65 : Loss : 0.1984, Acc : 0.8000, Test Acc : 0.8880
# Epoch   66 : Loss : 0.1970, Acc : 0.8000, Test Acc : 0.8880
# Epoch   67 : Loss : 0.1957, Acc : 0.8000, Test Acc : 0.8880
# Epoch   68 : Loss : 0.1944, Acc : 0.8000, Test Acc : 0.8880
# Epoch   69 : Loss : 0.1932, Acc : 0.8000, Test Acc : 0.8920
# Epoch   70 : Loss : 0.1919, Acc : 0.8000, Test Acc : 0.8920
# Epoch   71 : Loss : 0.1908, Acc : 0.8000, Test Acc : 0.8880
# Epoch   72 : Loss : 0.1896, Acc : 0.9000, Test Acc : 0.8840
# Epoch   73 : Loss : 0.1885, Acc : 0.9000, Test Acc : 0.8800
# Epoch   74 : Loss : 0.1874, Acc : 0.9000, Test Acc : 0.8760
# Epoch   75 : Loss : 0.1864, Acc : 0.9000, Test Acc : 0.8720
# Epoch   76 : Loss : 0.1854, Acc : 0.9000, Test Acc : 0.8760
# Epoch   77 : Loss : 0.1845, Acc : 0.9000, Test Acc : 0.8760
# Epoch   78 : Loss : 0.1835, Acc : 0.9000, Test Acc : 0.8760
# Epoch   79 : Loss : 0.1827, Acc : 0.9000, Test Acc : 0.8760
# Epoch   80 : Loss : 0.1818, Acc : 0.9000, Test Acc : 0.8760
# Epoch   81 : Loss : 0.1810, Acc : 0.9000, Test Acc : 0.8760
# Epoch   82 : Loss : 0.1802, Acc : 0.9000, Test Acc : 0.8760
# Epoch   83 : Loss : 0.1794, Acc : 0.9000, Test Acc : 0.8760
# Epoch   84 : Loss : 0.1787, Acc : 0.9000, Test Acc : 0.8760
# Epoch   85 : Loss : 0.1779, Acc : 0.9000, Test Acc : 0.8720
# Epoch   86 : Loss : 0.1772, Acc : 0.9000, Test Acc : 0.8720
# Epoch   87 : Loss : 0.1765, Acc : 0.9000, Test Acc : 0.8640
# Epoch   88 : Loss : 0.1759, Acc : 0.9000, Test Acc : 0.8640
# Epoch   89 : Loss : 0.1752, Acc : 0.9000, Test Acc : 0.8640
# Epoch   90 : Loss : 0.1746, Acc : 0.9000, Test Acc : 0.8640
# Epoch   91 : Loss : 0.1741, Acc : 0.9000, Test Acc : 0.8600
# Epoch   92 : Loss : 0.1734, Acc : 0.9000, Test Acc : 0.8600
# Epoch  130 : Loss : 0.1571, Acc : 0.9000, Test Acc : 0.8560
# Epoch  131 : Loss : 0.1567, Acc : 0.9000, Test Acc : 0.8560
# Epoch  132 : Loss : 0.1564, Acc : 0.9000, Test Acc : 0.8560
# Epoch  133 : Loss : 0.1561, Acc : 0.9000, Test Acc : 0.8560
# Epoch  134 : Loss : 0.1557, Acc : 0.9000, Test Acc : 0.8560
# Epoch  135 : Loss : 0.1554, Acc : 0.9000, Test Acc : 0.8560
# Epoch  136 : Loss : 0.1550, Acc : 0.9000, Test Acc : 0.8560
# Epoch  137 : Loss : 0.1547, Acc : 0.9000, Test Acc : 0.8560
# Epoch  138 : Loss : 0.1544, Acc : 0.9000, Test Acc : 0.8560
# Epoch  139 : Loss : 0.1540, Acc : 0.9000, Test Acc : 0.8560
# Epoch  140 : Loss : 0.1537, Acc : 0.9000, Test Acc : 0.8560
# Epoch  141 : Loss : 0.1534, Acc : 0.9000, Test Acc : 0.8560
# Epoch  142 : Loss : 0.1530, Acc : 0.9000, Test Acc : 0.8560
# Epoch  143 : Loss : 0.1527, Acc : 0.9000, Test Acc : 0.8560
# Epoch  144 : Loss : 0.1524, Acc : 0.9000, Test Acc : 0.8560
# Epoch  145 : Loss : 0.1520, Acc : 0.9000, Test Acc : 0.8560
# Epoch  146 : Loss : 0.1517, Acc : 0.9000, Test Acc : 0.8560
# Epoch  147 : Loss : 0.1514, Acc : 0.9000, Test Acc : 0.8560
# Epoch  148 : Loss : 0.1511, Acc : 0.9000, Test Acc : 0.8560
# Epoch  149 : Loss : 0.1507, Acc : 0.9000, Test Acc : 0.8560

# %%
# Affichage des données
plt.plot(x_train_unlab[y_train_unlab==0,0], x_train_unlab[y_train_unlab==0,1], 'b.')
plt.plot(x_train_unlab[y_train_unlab==1,0], x_train_unlab[y_train_unlab==1,1], 'r.')

plt.plot(x_test[y_test==0,0], x_test[y_test==0,1], 'b+')
plt.plot(x_test[y_test==1,0], x_test[y_test==1,1], 'r+')

plt.plot(x_train_lab[y_train_lab==0,0], x_train_lab[y_train_lab==0,1], 'b.', markersize=30)
plt.plot(x_train_lab[y_train_lab==1,0], x_train_lab[y_train_lab==1,1], 'r.', markersize=30)

plt.show()

#Affichage de la frontière de décision
plot_decision_regions(x_train_unlab, y_train_unlab, clf=model, legend=2)
plt.show()
# Out:
# 9600/9600 [==============================] - 17s 2ms/step

# %% [markdown]
# # Minimisation de l'entropie

# %% [markdown]
# Nous allons dans cette partie mettre en place le mécanisme de minimisation d'entropie, conjointement à la minimisation de l'entropie croisée.
#
# Pour commencer, implémentez la fonction de coût qui calcule l'entropie des prédictions du réseau $y_{pred}$

# %%
import tensorflow as tf

# Calcul de l'entropie de y_pred
# A COMPLETER
def entropy_loss(y_pred):
    return -tf.reduce_mean(y_pred * tf.math.log(y_pred))

# %% [markdown]
# **Travail à faire :** Reprenez maintenant la boucle d'apprentissage supervisé et introduisez la minimisation d'entropie pour régulariser l'apprentissage.

# %%
import tensorflow as tf
from tensorflow import keras
import math

# Données et modèle du problème des 2 clusters
x_train_lab, y_train_lab, x_train_unlab, y_train_unlab, x_test, y_test = generate_2moons_dataset(num_lab = 10, num_unlab=740, num_test=250)
model = create_model_2moons()

# Hyperparamètres de l'apprentissage
epochs = 150
batch_size = 16
if batch_size < x_train_lab.shape[0]:
  steps_per_epoch = math.floor(x_train_lab.shape[0]/batch_size)
else:
  steps_per_epoch = 1
  batch_size = x_train_lab.shape[0]

# Instanciation d'un optimiseur et d'une fonction de coût.
optimizer = keras.optimizers.Adam(learning_rate=1e-2)
loss_fn = keras.losses.BinaryCrossentropy()

# Préparation des métriques pour le suivi de la performance du modèle.
train_acc_metric = keras.metrics.BinaryAccuracy()
test_acc_metric = keras.metrics.BinaryAccuracy()

# Indices de l'ensemble labellisé
indices = np.arange(x_train_lab.shape[0])

# Boucle sur les epochs
for epoch in range(epochs):

  # A chaque nouvelle epoch, on randomise les indices de l'ensemble labellisé
  np.random.shuffle(indices)

  # Et on recommence à cumuler la loss
  cum_loss_value = 0

  for step in range(steps_per_epoch):

    # Sélection des données du prochain batch
    x_batch = x_train_lab[indices[step*batch_size: (step+1)*batch_size]]
    y_batch = y_train_lab[indices[step*batch_size: (step+1)*batch_size]]

    # Etape nécessaire pour comparer y_batch à la sortie du réseau
    y_batch = np.expand_dims(y_batch, 1)

    # Les opérations effectuées par le modèle dans ce bloc sont suivies et permettront
    # la différentiation automatique.
    with tf.GradientTape() as tape:

      # Application du réseau aux données d'entrée
      y_pred = model(x_batch, training=True)  # Logits for this minibatch

      # Calcul de la fonction de perte sur ce batch
      loss_value = loss_fn(y_batch, y_pred) + entropy_loss(y_pred)

      # Calcul des gradients par différentiation automatique
      grads = tape.gradient(loss_value, model.trainable_weights)

      # Réalisation d'une itération de la descente de gradient (mise à jour des paramètres du réseau)
      optimizer.apply_gradients(zip(grads, model.trainable_weights))

      # Mise à jour de la métrique
      train_acc_metric.update_state(y_batch, y_pred)

      cum_loss_value = cum_loss_value + loss_value

  # Calcul de la précision à la fin de l'epoch
  train_acc = train_acc_metric.result()

  # Calcul de la précision sur l'ensemble de test à la fin de l'epoch
  test_logits = model(x_test, training=False)
  test_acc_metric.update_state(np.expand_dims(y_test, 1), test_logits)
  test_acc = test_acc_metric.result()

  print("Epoch %4d : Loss : %.4f, Acc : %.4f, Test Acc : %.4f" % (epoch, float(cum_loss_value/steps_per_epoch), float(train_acc), float(test_acc)))

  # Remise à zéro des métriques pour la prochaine epoch
  train_acc_metric.reset_state()
  test_acc_metric.reset_state()
# Out:
# Epoch    0 : Loss : 0.9469, Acc : 0.7000, Test Acc : 0.5120
# Epoch    1 : Loss : 0.9214, Acc : 0.7000, Test Acc : 0.5120
# Epoch    2 : Loss : 0.8971, Acc : 0.7000, Test Acc : 0.5120
# Epoch    3 : Loss : 0.8739, Acc : 0.7000, Test Acc : 0.5120
# Epoch    4 : Loss : 0.8520, Acc : 0.7000, Test Acc : 0.5120
# Epoch    5 : Loss : 0.8311, Acc : 0.7000, Test Acc : 0.5120
# Epoch    6 : Loss : 0.8115, Acc : 0.7000, Test Acc : 0.5120
# Epoch    7 : Loss : 0.7928, Acc : 0.7000, Test Acc : 0.5120
# Epoch    8 : Loss : 0.7748, Acc : 0.7000, Test Acc : 0.5120
# Epoch    9 : Loss : 0.7576, Acc : 0.7000, Test Acc : 0.5120
# Epoch   10 : Loss : 0.7412, Acc : 0.7000, Test Acc : 0.5120
# Epoch   11 : Loss : 0.7258, Acc : 0.7000, Test Acc : 0.5120
# Epoch   12 : Loss : 0.7113, Acc : 0.7000, Test Acc : 0.5120
# Epoch   13 : Loss : 0.6982, Acc : 0.7000, Test Acc : 0.5120
# Epoch   14 : Loss : 0.6863, Acc : 0.7000, Test Acc : 0.5120
# Epoch  127 : Loss : 0.2319, Acc : 0.9000, Test Acc : 0.8360
# Epoch  128 : Loss : 0.2305, Acc : 0.9000, Test Acc : 0.8360
# Epoch  129 : Loss : 0.2290, Acc : 0.9000, Test Acc : 0.8320
# Epoch  130 : Loss : 0.2275, Acc : 0.9000, Test Acc : 0.8320
# Epoch  131 : Loss : 0.2262, Acc : 0.9000, Test Acc : 0.8280
# Epoch  132 : Loss : 0.2248, Acc : 0.9000, Test Acc : 0.8280
# Epoch  133 : Loss : 0.2233, Acc : 0.9000, Test Acc : 0.8280
# Epoch  134 : Loss : 0.2218, Acc : 0.9000, Test Acc : 0.8280
# Epoch  135 : Loss : 0.2204, Acc : 0.9000, Test Acc : 0.8280
# Epoch  136 : Loss : 0.2191, Acc : 0.9000, Test Acc : 0.8280
# Epoch  137 : Loss : 0.2177, Acc : 0.9000, Test Acc : 0.8280
# Epoch  138 : Loss : 0.2162, Acc : 0.9000, Test Acc : 0.8320
# Epoch  139 : Loss : 0.2147, Acc : 0.9000, Test Acc : 0.8320
# Epoch  140 : Loss : 0.2135, Acc : 0.9000, Test Acc : 0.8320
# Epoch  141 : Loss : 0.2123, Acc : 0.9000, Test Acc : 0.8320
# Epoch  142 : Loss : 0.2109, Acc : 0.9000, Test Acc : 0.8320
# Epoch  143 : Loss : 0.2094, Acc : 0.9000, Test Acc : 0.8320
# Epoch  144 : Loss : 0.2080, Acc : 0.9000, Test Acc : 0.8320
# Epoch  145 : Loss : 0.2068, Acc : 0.9000, Test Acc : 0.8280
# Epoch  146 : Loss : 0.2054, Acc : 0.9000, Test Acc : 0.8280
# Epoch  147 : Loss : 0.2040, Acc : 0.9000, Test Acc : 0.8280
# Epoch  148 : Loss : 0.2027, Acc : 0.9000, Test Acc : 0.8280
# Epoch  149 : Loss : 0.2015, Acc : 0.9000, Test Acc : 0.8280

# %%
# Affichage des données
plt.plot(x_train_unlab[y_train_unlab==0,0], x_train_unlab[y_train_unlab==0,1], 'b.')
plt.plot(x_train_unlab[y_train_unlab==1,0], x_train_unlab[y_train_unlab==1,1], 'r.')

plt.plot(x_test[y_test==0,0], x_test[y_test==0,1], 'b+')
plt.plot(x_test[y_test==1,0], x_test[y_test==1,1], 'r+')

plt.plot(x_train_lab[y_train_lab==0,0], x_train_lab[y_train_lab==0,1], 'b.', markersize=30)
plt.plot(x_train_lab[y_train_lab==1,0], x_train_lab[y_train_lab==1,1], 'r.', markersize=30)

plt.show()

#Affichage de la frontière de décision
plot_decision_regions(x_train_unlab, y_train_unlab, clf=model, legend=2)
plt.show()
# Out:
# 9600/9600 [==============================] - 18s 2ms/step

# %% [markdown]
# # $\Pi$-Modèle
#
# Nous allons maintenant tenter d'utiliser un 2nd algorithme semi-supervisé supposé être plus efficace, il s'agit de l'algorithme du $\Pi$-Modèle, donc la version détaillée est présentée ci-dessous (en VO).
#
# <img src="https://drive.google.com/uc?id=13VhlBYwA6YIYGzKI81Jom_jTiuhOypEg">
# <caption><center> Figure 2 : Pseudo-code de l'algorithme du $\Pi$-Modèle</center></caption>

# %% [markdown]
# Ci-dessous, la boucle d'entraînement détaillée est reprise et contient un squelette du code à réaliser pour implémenter le $\Pi$-Modèle.
#
# **Travail à faire :** Complétez le squelette de l'algorithme du $\Pi$-Modèle pour pouvoir tester ce nouvel algorithme.

# %%
# Nombre d'epochs de l'apprentissage
epochs = 2000
# Nombre de données non-labellisées par batch
bs_unlab = 100
# Nombre de données labellisées par batch
bs_lab = 10
# Taille du batch
batch_size = bs_lab + bs_unlab
# Valeur initiale du paramètre de contrôle de l'importance de la régularisation non-supervisée
lambda_t = 0

# Données et modèle du problème des 2 clusters
x_train_lab, y_train_lab, x_train_unlab, y_train_unlab, x_test, y_test = generate_2moons_dataset(num_lab = 10, num_unlab=740, num_test=250)
model = create_model_2moons()

# Nombre de batches par epochs
steps_per_epochs = int(np.floor(x_train_lab.shape[0]/bs_lab))
# Instanciation d'un optimiseur et d'une fonction de coût.
optimizer = keras.optimizers.Adam(learning_rate=1e-2)
# ICI ON A BESOIN DE DEUX FONCTIONS DE COUT :
# L'une pour la partie supervisée de la perte
loss_sup = keras.losses.BinaryCrossentropy()
# L'autre pour la partie non-supervisée de la perte
loss_unsup =  keras.losses.MeanSquaredError()

# Préparation des métriques pour le suivi de la performance du modèle.
train_acc_metric = keras.metrics.BinaryAccuracy()
val_acc_metric = keras.metrics.BinaryAccuracy()

# Indices de l'ensemble non labellisé
indices_lab = np.arange(x_train_lab.shape[0])
# Indices de l'ensemble non labellisé
indices_unlab = np.arange(x_train_unlab.shape[0])

for epoch in range(epochs):

  for b in range(steps_per_epochs):

    # Les données d'un batch sont constituées de l'intégralité de nos données labellisées...
    x_batch_lab = x_train_lab[indices_lab[b*bs_lab:(b+1)*bs_lab]]
    y_batch_lab = y_train_lab[indices_lab[b*bs_lab:(b+1)*bs_lab]]
    # ... ainsi que de données non-labellisées !
    x_batch_unlab = x_train_unlab[indices[b*bs_unlab:(b+1)*bs_unlab]]

    # On forme notre batch en concaténant les données labellisées et non labellisées
    x_batch = np.concatenate((x_batch_lab, x_batch_unlab), axis=0)

    # On forme également un batch alternatif constitué des mêmes données bruitées
    # Le bruit ici sera simplement obtenu avec np.rand()
    # Attention à l'échelle du bruit !
    x_batch_noisy = x_batch + np.random.rand(x_batch.shape[0], x_batch.shape[1])*0.1

    # Les opérations effectuées par le modèle dans ce bloc sont suivies et permettront
    # la différentiation automatique.
    with tf.GradientTape() as tape:

      # Application du réseau aux données d'entrée
      y_pred = model(x_batch, training=True)
      # Ne pas oublier de le faire également sur le 2e batch !
      y_pred_noisy = model(x_batch_noisy, training=True)

      # Calcul de la fonction de perte sur ce batch
      sup_term = loss_sup(np.expand_dims(y_batch_lab, 1), y_pred[0:bs_lab])
      unsup_term = loss_unsup(y_pred[bs_lab:], y_pred_noisy[bs_lab:])

      loss_value = sup_term + lambda_t * unsup_term

      # Calcul des gradients par différentiation automatique
      grads = tape.gradient(loss_value, model.trainable_weights)

      # Réalisation d'une itération de la descente de gradient (mise à jour des paramètres du réseau)
      optimizer.apply_gradients(zip(grads, model.trainable_weights))

      # Mise à jour de la métrique
      train_acc_metric.update_state(np.expand_dims(y_batch_lab, 1), y_pred[0:bs_lab])


  # Calcul de la précision à la fin de l'epoch
  train_acc = train_acc_metric.result()
  # Calcul de la précision sur l'ensemble de validation à la fin de l'epoch
  val_logits = model(x_test, training=False)
  val_acc_metric.update_state(np.expand_dims(y_test, 1), val_logits)
  val_acc = val_acc_metric.result()

  print("Epoch %4d : Loss : %.4f, Acc : %.4f, Val Acc : %.4f" % (epoch, float(loss_value), float(train_acc), float(val_acc)))

  # Remise à zéro des métriques pour la prochaine epoch
  train_acc_metric.reset_state()
  val_acc_metric.reset_state()

  # Mise à jour du paramètre de contrôle de l'importance de la régularisation non-supervisée
  # Il augmente progressivement !
  if lambda_t < 1:
    if epoch > 100:
      lambda_t = lambda_t + 0.01
# Out:
# Epoch    0 : Loss : 0.6667, Acc : 0.7000, Val Acc : 0.5120
# Epoch    1 : Loss : 0.6452, Acc : 0.7000, Val Acc : 0.5120
# Epoch    2 : Loss : 0.6252, Acc : 0.7000, Val Acc : 0.5120
# Epoch    3 : Loss : 0.6069, Acc : 0.7000, Val Acc : 0.5120
# Epoch    4 : Loss : 0.5899, Acc : 0.7000, Val Acc : 0.5120
# Epoch    5 : Loss : 0.5743, Acc : 0.7000, Val Acc : 0.5120
# Epoch    6 : Loss : 0.5597, Acc : 0.7000, Val Acc : 0.5120
# Epoch    7 : Loss : 0.5463, Acc : 0.7000, Val Acc : 0.5520
# Epoch    8 : Loss : 0.5337, Acc : 0.7000, Val Acc : 0.6400
# Epoch    9 : Loss : 0.5219, Acc : 0.7000, Val Acc : 0.6560
# Epoch   10 : Loss : 0.5106, Acc : 0.7000, Val Acc : 0.6840
# Epoch   11 : Loss : 0.5000, Acc : 0.7000, Val Acc : 0.7240
# Epoch   12 : Loss : 0.4899, Acc : 0.7000, Val Acc : 0.7520
# Epoch   13 : Loss : 0.4803, Acc : 0.8000, Val Acc : 0.7680
# Epoch   14 : Loss : 0.4710, Acc : 0.9000, Val Acc : 0.7760
# Epoch   15 : Loss : 0.4619, Acc : 0.9000, Val Acc : 0.7880
# Epoch   16 : Loss : 0.4532, Acc : 0.9000, Val Acc : 0.7920
# Epoch   17 : Loss : 0.4448, Acc : 0.9000, Val Acc : 0.8000
# Epoch   18 : Loss : 0.4367, Acc : 0.9000, Val Acc : 0.8200
# Epoch   19 : Loss : 0.4288, Acc : 0.9000, Val Acc : 0.8160
# Epoch   20 : Loss : 0.4214, Acc : 0.9000, Val Acc : 0.8200
# Epoch   21 : Loss : 0.4142, Acc : 0.9000, Val Acc : 0.8280
# Epoch   22 : Loss : 0.4073, Acc : 0.9000, Val Acc : 0.8360
# Epoch   23 : Loss : 0.4005, Acc : 0.9000, Val Acc : 0.8360
# Epoch   24 : Loss : 0.3940, Acc : 0.9000, Val Acc : 0.8360
# Epoch   25 : Loss : 0.3877, Acc : 0.9000, Val Acc : 0.8320
# Epoch   26 : Loss : 0.3816, Acc : 0.9000, Val Acc : 0.8280
# Epoch   27 : Loss : 0.3757, Acc : 0.9000, Val Acc : 0.8280
# Epoch   28 : Loss : 0.3699, Acc : 0.9000, Val Acc : 0.8320
# Epoch   29 : Loss : 0.3643, Acc : 0.9000, Val Acc : 0.8320
# Epoch   30 : Loss : 0.3588, Acc : 0.9000, Val Acc : 0.8280
# Epoch   31 : Loss : 0.3535, Acc : 0.9000, Val Acc : 0.8320
# Epoch   32 : Loss : 0.3483, Acc : 0.9000, Val Acc : 0.8360
# Epoch   33 : Loss : 0.3431, Acc : 0.9000, Val Acc : 0.8360
: Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1828 : Loss : 0.0003, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1829 : Loss : 0.0003, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1830 : Loss : 0.0003, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1831 : Loss : 0.0003, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1832 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1833 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1834 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1835 : Loss : 0.0003, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1836 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1837 : Loss : 0.0003, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1838 : Loss : 0.0003, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1839 : Loss : 0.0003, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1840 : Loss : 0.0003, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1841 : Loss : 0.0003, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1842 : Loss : 0.0003, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1843 : Loss : 0.0003, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1844 : Loss : 0.0003, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1845 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1846 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1847 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1848 : Loss : 0.0003, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1849 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1850 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1851 : Loss : 0.0003, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1852 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1853 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1854 : Loss : 0.0003, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1855 : Loss : 0.0003, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1856 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1857 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1858 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1859 : Loss : 0.0003, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1860 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1861 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1862 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1863 : Loss : 0.0003, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1864 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1865 : Loss : 0.0003, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1866 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1867 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1868 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1869 : Loss : 0.0003, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1870 : Loss : 0.0003, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1871 : Loss : 0.0003, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1872 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1873 : Loss : 0.0003, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1874 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1875 : Loss : 0.0003, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1876 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1877 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1878 : Loss : 0.0003, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1879 : Loss : 0.0003, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1880 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1881 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1882 : Loss : 0.0003, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1883 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1884 : Loss : 0.0003, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1885 : Loss : 0.0003, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1886 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1887 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1888 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1889 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1890 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1891 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1892 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1893 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1894 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1895 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1896 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1897 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1898 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1899 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1900 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1901 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1902 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1903 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1904 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1905 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1906 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1907 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1908 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1909 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1910 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1911 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1912 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1913 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1914 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1915 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1916 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1917 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1918 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1919 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1920 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1921 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1922 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1923 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1924 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1925 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1926 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1927 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1928 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1929 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1930 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1931 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1932 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1933 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1934 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1935 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1936 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1937 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1938 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1939 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1940 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1941 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1942 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1943 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1944 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1945 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1946 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1947 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1948 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1949 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1950 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1951 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1952 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1953 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1954 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1955 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1956 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1957 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1958 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1959 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1960 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1961 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1962 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1963 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1964 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1965 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1966 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1967 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1968 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1969 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1970 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1971 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1972 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1973 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1974 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1975 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1976 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1977 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1978 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1979 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1980 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1981 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1982 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1983 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1984 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1985 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1986 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1987 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1988 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1989 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1990 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1991 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1992 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1993 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1994 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1995 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1996 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1997 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1998 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840
# Epoch 1999 : Loss : 0.0002, Acc : 1.0000, Val Acc : 0.7840

# %%
# Affichage des données
plt.plot(x_train_unlab[y_train_unlab==0,0], x_train_unlab[y_train_unlab==0,1], 'b.')
plt.plot(x_train_unlab[y_train_unlab==1,0], x_train_unlab[y_train_unlab==1,1], 'r.')

plt.plot(x_test[y_test==0,0], x_test[y_test==0,1], 'b+')
plt.plot(x_test[y_test==1,0], x_test[y_test==1,1], 'r+')

plt.plot(x_train_lab[y_train_lab==0,0], x_train_lab[y_train_lab==0,1], 'b.', markersize=30)
plt.plot(x_train_lab[y_train_lab==1,0], x_train_lab[y_train_lab==1,1], 'r.', markersize=30)

plt.show()

#Affichage de la frontière de décision
plot_decision_regions(x_train_unlab, y_train_unlab, clf=model, legend=2)
plt.show()
# Out:
# 9600/9600 [==============================] - 18s 2ms/step

# %% [markdown]
# # MNIST

# %% [markdown]
# Pour adapter l'algorithme du $\Pi$-modèle à MNIST, nous allons devoir remplacer le bruitage des données par de l'augmentation de données.
#
# Commencez par remplir l'ImageDataGenerator (à vous de voir la doc) avec des transformations pertinentes. **Attention** cette étape est cruciale pour obtenir de bons résultats. Il faut intégrer les augmentations les plus fortes possibles, mais être certain qu'elles ne modifient pas le label du chiffre !

# %%
from tensorflow.keras.datasets import mnist
import numpy as np
from sklearn.model_selection import train_test_split

def generate_mnist_dataset(num_lab = 100):

  # Chargement et normalisation (entre 0 et 1) des données de la base de données MNIST
  (x_train, y_train), (x_test, y_test) = mnist.load_data()

  x_train = np.expand_dims(x_train.astype('float32') / 255., 3)
  x_test = np.expand_dims(x_test.astype('float32') / 255., 3)

  x_train_lab, x_train_unlab, y_train_lab, y_train_unlab = train_test_split(x_train, y_train, test_size=(x_train.shape[0]-num_lab)/x_train.shape[0], random_state=2)

  return x_train_lab, y_train_lab, x_train_unlab, y_train_unlab, x_test, y_test

x_train_lab, y_train_lab, x_train_unlab, y_train_unlab, x_test, y_test = generate_mnist_dataset()

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

train_datagen = ImageDataGenerator(
    # A COMPLETER
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=False,
    vertical_flip=False,
    fill_mode='nearest')

x = x_train_lab[0:10]
plt.imshow(x[0, : ,: ,0])
plt.show()
x_aug = train_datagen.flow(x, shuffle=False, batch_size=10).__next__()
plt.imshow(x_aug[0, : ,: ,0])
plt.show()

# %% [markdown]
# **Travail à faire :** Reprenez maintenant le squelette précédent pour l'adapter à MNIST, en intégrant l'augmentation (à la place du bruitage des données). N'oubliez pas également de modifier les fonctions de coût !

# %%
# Nombre d'epochs de l'apprentissage
epochs = 2000
# Nombre de données non-labellisées par batch
bs_unlab = 100
# Nombre de données labellisées par batch
bs_lab = 10
# Taille du batch
batch_size = bs_lab + bs_unlab
# Valeur initiale du paramètre de contrôle de l'importance de la régularisation non-supervisée
lambda_t = 0

# Données et modèle du problème des 2 clusters
x_train_lab, y_train_lab, x_train_unlab, y_train_unlab, x_test, y_test = generate_mnist_dataset()
model = create_model_mnist()

# Nombre de batches par epochs
steps_per_epochs = int(np.floor(x_train_lab.shape[0]/bs_lab))
# Instanciation d'un optimiseur et d'une fonction de coût.
optimizer = keras.optimizers.Adam(learning_rate=1e-2)
# ICI ON A BESOIN DE DEUX FONCTIONS DE COUT :
# L'une pour la partie supervisée de la perte
loss_sup = keras.losses.SparseCategoricalCrossentropy()
# L'autre pour la partie non-supervisée de la perte
loss_unsup =  keras.losses.MeanSquaredError()

# Préparation des métriques pour le suivi de la performance du modèle.
train_acc_metric = keras.metrics.BinaryAccuracy()
val_acc_metric = keras.metrics.BinaryAccuracy()

# Indices de l'ensemble non labellisé
indices_lab = np.arange(x_train_lab.shape[0])
# Indices de l'ensemble non labellisé
indices_unlab = np.arange(x_train_unlab.shape[0])

for epoch in range(epochs):

  for b in range(steps_per_epochs):

    # Les données d'un batch sont constituées de l'intégralité de nos données labellisées...
    x_batch_lab = x_train_lab[indices_lab[b*bs_lab:(b+1)*bs_lab]]
    y_batch_lab = y_train_lab[indices_lab[b*bs_lab:(b+1)*bs_lab]]
    # ... ainsi que de données non-labellisées !
    x_batch_unlab = x_train_unlab[indices[b*bs_unlab:(b+1)*bs_unlab]]

    # On forme notre batch en concaténant les données labellisées et non labellisées
    x_batch = np.concatenate((x_batch_lab, x_batch_unlab), axis=0)

    # On forme également un batch alternatif constitué des mêmes données bruitées
    # Le bruit ici sera les données augmentées
    # Attention à l'échelle du bruit !
    x_batch_noisy = train_datagen.flow(x_batch, shuffle=False, batch_size=batch_size).__next__()

    # Les opérations effectuées par le modèle dans ce bloc sont suivies et permettront
    # la différentiation automatique.
    with tf.GradientTape() as tape:

      # Application du réseau aux données d'entrée
      y_pred = model(x_batch, training=True)
      # Ne pas oublier de le faire également sur le 2e batch !
      y_pred_noisy = model(x_batch_noisy, training=True)

      # Calcul de la fonction de perte sur ce batch
      sup_term = loss_sup(np.expand_dims(y_batch_lab, 1), y_pred[0:bs_lab])
      unsup_term = loss_unsup(y_pred[bs_lab:], y_pred_noisy[bs_lab:])

      loss_value = sup_term + lambda_t * unsup_term

      # Calcul des gradients par différentiation automatique
      grads = tape.gradient(loss_value, model.trainable_weights)

      # Réalisation d'une itération de la descente de gradient (mise à jour des paramètres du réseau)
      optimizer.apply_gradients(zip(grads, model.trainable_weights))

      # Mise à jour de la métrique
      train_acc_metric.update_state(np.expand_dims(y_batch_lab, 1), y_pred[0:bs_lab])


  # Calcul de la précision à la fin de l'epoch
  train_acc = train_acc_metric.result()
  # Calcul de la précision sur l'ensemble de validation à la fin de l'epoch
  val_logits = model(x_test, training=False)
  val_acc_metric.update_state(np.expand_dims(y_test, 1), val_logits)
  val_acc = val_acc_metric.result()

  print("Epoch %4d : Loss : %.4f, Acc : %.4f, Val Acc : %.4f" % (epoch, float(loss_value), float(train_acc), float(val_acc)))

  # Remise à zéro des métriques pour la prochaine epoch
  train_acc_metric.reset_state()
  val_acc_metric.reset_state()

  # Mise à jour du paramètre de contrôle de l'importance de la régularisation non-supervisée
  # Il augmente progressivement !
  if lambda_t < 1:
    if epoch > 100:
      lambda_t = lambda_t + 0.01
# Out:
# Epoch    0 : Loss : 2.2348, Acc : 0.1400, Val Acc : 0.0980
# Epoch    1 : Loss : 1.0994, Acc : 0.1340, Val Acc : 0.0942
# Epoch    2 : Loss : 0.3196, Acc : 0.1330, Val Acc : 0.0986
# Epoch    3 : Loss : 0.2463, Acc : 0.1340, Val Acc : 0.0998
# Epoch    4 : Loss : 0.1226, Acc : 0.1350, Val Acc : 0.1004
# Epoch    5 : Loss : 0.0826, Acc : 0.1350, Val Acc : 0.0998
# Epoch    6 : Loss : 0.0514, Acc : 0.1350, Val Acc : 0.0996
# Epoch    7 : Loss : 0.0008, Acc : 0.1350, Val Acc : 0.0996
# Epoch    8 : Loss : 0.0326, Acc : 0.1350, Val Acc : 0.0996
# Epoch    9 : Loss : 0.0084, Acc : 0.1350, Val Acc : 0.0999
# Epoch   10 : Loss : 0.4374, Acc : 0.1350, Val Acc : 0.0998
# Epoch   11 : Loss : 0.3942, Acc : 0.1350, Val Acc : 0.0999
# Epoch   12 : Loss : 0.0451, Acc : 0.1350, Val Acc : 0.0997
# Epoch   13 : Loss : 0.0030, Acc : 0.1350, Val Acc : 0.0996
# Epoch   14 : Loss : 0.0001, Acc : 0.1350, Val Acc : 0.0996
# Epoch   15 : Loss : 0.0001, Acc : 0.1350, Val Acc : 0.0997
# Epoch   16 : Loss : 0.0007, Acc : 0.1350, Val Acc : 0.0996
# Epoch   17 : Loss : 0.0008, Acc : 0.1350, Val Acc : 0.0997
# Epoch   18 : Loss : 0.0009, Acc : 0.1350, Val Acc : 0.0997
# Epoch   19 : Loss : 0.0004, Acc : 0.1350, Val Acc : 0.0998
# Epoch   20 : Loss : 0.0001, Acc : 0.1350, Val Acc : 0.0997
# Epoch   21 : Loss : 0.0001, Acc : 0.1350, Val Acc : 0.0997
# Epoch   22 : Loss : 0.0001, Acc : 0.1350, Val Acc : 0.0998
# Epoch   23 : Loss : 0.0001, Acc : 0.1350, Val Acc : 0.0998
# Epoch   24 : Loss : 0.0001, Acc : 0.1350, Val Acc : 0.0998
# Epoch   25 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0998
# Epoch   26 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0998
# Epoch   27 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0998
# Epoch   28 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0998
# Epoch   29 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0998
# Epoch   30 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0998
# Epoch   31 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0998
# Epoch   32 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0998
# Epoch   33 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0998
# Epoch   34 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0998
# Epoch   35 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0998
# Epoch   36 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0998
# Epoch   37 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0998
# Epoch   38 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0998
# Epoch   39 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0998
# Epoch   40 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0998
# Epoch   41 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0998
# Epoch   42 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0998
# Epoch   43 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0998
# Epoch   44 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0998
# Epoch   45 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0998
# Epoch   46 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0998
# Epoch   47 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0998
# Epoch   48 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0998
# Epoch   49 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0998
# Epoch   50 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0998
# Epoch   51 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0998
# Epoch   52 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0998
# Epoch   53 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0998
# Epoch   54 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0998
# Epoch   55 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0998
# Epoch   56 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0998
# Epoch   57 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0998
# Epoch   58 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0998
# Epoch   59 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0998
# Epoch   60 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0998
# Epoch   61 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0998
# Epoch   62 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0998
# Epoch   63 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0998
# Epoch   64 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0998
# Epoch   65 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0997
# Epoch   66 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0997
# Epoch   67 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0998
# Epoch   68 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0998
# Epoch   69 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0997
# Epoch
: Loss : 0.0001, Acc : 0.1350, Val Acc : 0.0995
# Epoch  442 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  443 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0995
# Epoch  444 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  445 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  446 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  447 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0995
# Epoch  448 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  449 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  450 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  451 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  452 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  453 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0995
# Epoch  454 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0995
# Epoch  455 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0995
# Epoch  456 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0995
# Epoch  457 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0995
# Epoch  458 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  459 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0997
# Epoch  460 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  461 : Loss : 1.6118, Acc : 0.1350, Val Acc : 0.0995
# Epoch  462 : Loss : 1.3585, Acc : 0.1350, Val Acc : 0.0998
# Epoch  463 : Loss : 0.5983, Acc : 0.1350, Val Acc : 0.0992
# Epoch  464 : Loss : 0.8941, Acc : 0.1330, Val Acc : 0.0990
# Epoch  465 : Loss : 0.0000, Acc : 0.1360, Val Acc : 0.0991
# Epoch  466 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  467 : Loss : 2.6216, Acc : 0.1350, Val Acc : 0.0995
# Epoch  468 : Loss : 0.0004, Acc : 0.1350, Val Acc : 0.0991
# Epoch  469 : Loss : 1.7611, Acc : 0.1350, Val Acc : 0.0990
# Epoch  470 : Loss : 0.0235, Acc : 0.1350, Val Acc : 0.0998
# Epoch  471 : Loss : 0.1761, Acc : 0.1350, Val Acc : 0.0998
# Epoch  472 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  473 : Loss : 0.0005, Acc : 0.1350, Val Acc : 0.0995
# Epoch  474 : Loss : 3.7393, Acc : 0.1350, Val Acc : 0.0998
# Epoch  475 : Loss : 0.0001, Acc : 0.1350, Val Acc : 0.1022
# Epoch  476 : Loss : 0.0014, Acc : 0.1390, Val Acc : 0.1038
# Epoch  477 : Loss : 1.6123, Acc : 0.1380, Val Acc : 0.1031
# Epoch  478 : Loss : 0.1377, Acc : 0.1360, Val Acc : 0.1015
# Epoch  479 : Loss : 1.6122, Acc : 0.1350, Val Acc : 0.1011
# Epoch  480 : Loss : 1.9525, Acc : 0.1350, Val Acc : 0.1006
# Epoch  481 : Loss : 1.7015, Acc : 0.1350, Val Acc : 0.1008
# Epoch  482 : Loss : 1.6118, Acc : 0.1350, Val Acc : 0.1008
# Epoch  483 : Loss : 1.6118, Acc : 0.1350, Val Acc : 0.1007
# Epoch  484 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.1014
# Epoch  485 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.1015
# Epoch  486 : Loss : 0.0002, Acc : 0.1350, Val Acc : 0.1011
# Epoch  487 : Loss : 0.0003, Acc : 0.1350, Val Acc : 0.1009
# Epoch  488 : Loss : 0.0003, Acc : 0.1350, Val Acc : 0.1009
# Epoch  489 : Loss : 0.0001, Acc : 0.1350, Val Acc : 0.1009
# Epoch  490 : Loss : 0.0001, Acc : 0.1350, Val Acc : 0.1009
# Epoch  491 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.1009
# Epoch  492 : Loss : 0.0001, Acc : 0.1350, Val Acc : 0.1009
# Epoch  493 : Loss : 0.0002, Acc : 0.1350, Val Acc : 0.1009
# Epoch  494 : Loss : 0.0002, Acc : 0.1350, Val Acc : 0.1009
# Epoch  495 : Loss : 0.0002, Acc : 0.1350, Val Acc : 0.1008
# Epoch  496 : Loss : 0.0001, Acc : 0.1350, Val Acc : 0.1009
# Epoch  497 : Loss : 0.0001, Acc : 0.1350, Val Acc : 0.1009
# Epoch  498 : Loss : 0.0001, Acc : 0.1350, Val Acc : 0.1008
# Epoch  499 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.1007
# Epoch  500 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.1007
# Epoch  501 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.1007
# Epoch  502 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.1007
# Epoch  503 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.1008
# Epoch  504 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.1008
# Epoch  505 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.1008
# Epoch  506 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.1008
# Epoch  507 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.1008
# Epoch  508 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  509 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0997
# Epoch  510 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0997
# Epoch  511 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  512 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0995
# Epoch  513 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  514 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  515 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  516 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  517 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  518 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  519 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  520 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  521 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  522 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0997
# Epoch  523 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  524 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0997
# Epoch  525 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0997
# Epoch  526 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0997
# Epoch  527 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0997
# Epoch  528 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0997
# Epoch  529 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0997
# Epoch  530 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0997
# Epoch  531 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0997
# Epoch  532 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0995
# Epoch  533 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  534 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  535 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  536 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0997
# Epoch  537 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0997
# Epoch  538 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0997
# Epoch  539 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0997
# Epoch  540 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0997
# Epoch  541 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0997
# Epoch  542 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0997
# Epoch  543 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0997
# Epoch  544 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0997
# Epoch  545 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  546 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  547 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  548 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  549 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  550 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  551 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0997
# Epoch  552 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0997
# Epoch  553 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0997
# Epoch  554 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  555 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  556 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  557 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  558 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  559 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  560 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  561 : Loss : 0.4042, Acc : 0.1350, Val Acc : 0.0996
# Epoch  562 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  563 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  564 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0995
# Epoch  565 : Loss : 0.2198, Acc : 0.1350, Val Acc : 0.0996
# Epoch  566 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  567 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  568 : Loss : 0.0004, Acc : 0.1350, Val Acc : 0.0996
# Epoch  569 : Loss : 0.0007, Acc : 0.1350, Val Acc : 0.0995
# Epoch  570 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  571 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  572 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  573 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  574 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0995
# Epoch  575 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  576 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  577 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  578 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  579 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  580 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  581 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  582 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  583 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  584 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  585 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  586 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  587 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  588 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  589 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  590 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  591 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  592 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  593 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  594 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  595 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  596 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  597 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  598 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  599 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  600 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  601 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  602 : Loss : 0.0004, Acc : 0.1350, Val Acc : 0.0996
# Epoch  603 : Loss : 0.0895, Acc : 0.1350, Val Acc : 0.0996
# Epoch  604 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0999
# Epoch  605 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0994
# Epoch  606 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0993
# Epoch  607 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0994
# Epoch  608 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0994
# Epoch  609 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  610 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0994
# Epoch  611 : Loss : 1.6118, Acc : 0.1350, Val Acc : 0.0992
# Epoch  612 : Loss : 1.0427, Acc : 0.1350, Val Acc : 0.0986
# Epoch  613 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0999
# Epoch  614 : Loss : 1.6118, Acc : 0.1350, Val Acc : 0.1005
# Epoch  615 : Loss : 0.0049, Acc : 0.1350, Val Acc : 0.0998
# Epoch  616 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0997
# Epoch  617 : Loss : 0.0011, Acc : 0.1350, Val Acc : 0.0995
# Epoch  618 : Loss : 0.0835, Acc : 0.1350, Val Acc : 0.0997
# Epoch  619 : Loss : 0.0825, Acc : 0.1350, Val Acc : 0.1000
# Epoch  620 : Loss : 0.0796, Acc : 0.1350, Val Acc : 0.0998
# Epoch  621 : Loss : 0.0763, Acc : 0.1350, Val Acc : 0.1000
# Epoch  622 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.1000
# Epoch  623 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0998
# Epoch  624 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0997
# Epoch  625 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.1003
# Epoch  626 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.1003
# Epoch  627 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.1007
# Epoch  628 : Loss : 0.3318, Acc : 0.1350, Val Acc : 0.1009
# Epoch  629 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.1007
# Epoch  630 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.1009
# Epoch  631 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.1010
# Epoch  632 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.1006
# Epoch  633 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.1005
# Epoch  634 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.1004
# Epoch  635 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.1004
# Epoch  636 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  637 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  638 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  639 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0995
# Epoch  640 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  641 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  642 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  643 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  644 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0995
# Epoch  645 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  646 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  647 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0995
# Epoch  648 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0995
# Epoch  649 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  650 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  651 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  652 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  653 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  654 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  655 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  656 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  657 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  658 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  659 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  660 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  661 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  662 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  663 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  664 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  665 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  666 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  667 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  668 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  669 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  670 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  671 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  672 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  673 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  674 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  675 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  676 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  677 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  678 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  679 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  680 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  681 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  682 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  683 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  684 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  685 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  686 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  687 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  688 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  689 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  690 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  691 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  692 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  693 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  694 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  695 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0995
# Epoch  696 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  697 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  698 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  699 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0995
# Epoch  700 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0995
# Epoch  701 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  702 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  703 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  704 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  705 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  706 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  707 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  708 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0995
# Epoch  709 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  710 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  711 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  712 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  713 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  714 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  715 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0995
# Epoch  716 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0995
# Epoch  717 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0995
# Epoch  718 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0995
# Epoch  719 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  720 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  721 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  722 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  723 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  724 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  725 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  726 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  727 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  728 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  729 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  730 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  731 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  732 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  733 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  734 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  735 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  736 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  737 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  738 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  739 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  740 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  741 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  742 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0995
# Epoch  743 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0995
# Epoch  744 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  745 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  746 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  747 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  748 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  749 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  750 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  751 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  752 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  753 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  754 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  755 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  756 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  757 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  758 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  759 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  760 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  761 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  762 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  763 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  764 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  765 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  766 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  767 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  768 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  769 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  770 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  771 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  772 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  773 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0995
# Epoch  774 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  775 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0995
# Epoch  776 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  777 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  778 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  779 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  780 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  781 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  782 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  783 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  784 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  785 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  786 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  787 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  788 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0995
# Epoch  789 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  790 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  791 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# Epoch  792 : Loss : 0.0000, Acc : 0.1350, Val Acc : 0.0996
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[56], line 51
#      46 x_batch = np.concatenate((x_batch_lab, x_batch_unlab), axis=0)
#      48 # On forme également un batch alternatif constitué des mêmes données bruitées
#      49 # Le bruit ici sera les données augmentées
#      50 # Attention à l'échelle du bruit !
# ---> 51 x_batch_noisy = train_datagen.flow(x_batch, shuffle=False, batch_size=batch_size).__next__()
#      53 # Les opérations effectuées par le modèle dans ce bloc sont suivies et permettront
#      54 # la différentiation automatique.
#      55 with tf.GradientTape() as tape:
#      56
#      57   # Application du réseau aux données d'entrée
#
# File ~/.local/lib/python3.10/site-packages/keras/src/preprocessing/image.py:156, in Iterator.__next__(self, *args, **kwargs)
#     155 def __next__(self, *args, **kwargs):
# --> 156     return self.next(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/keras/src/preprocessing/image.py:168, in Iterator.next(self)
#     165     index_array = next(self.index_generator)
#     166 # The transformation of images is not under thread lock
#     167 # so it can be done in parallel
# --> 168 return self._get_batches_of_transformed_samples(index_array)
#
# File ~/.local/lib/python3.10/site-packages/keras/src/preprocessing/image.py:801, in NumpyArrayIterator._get_batches_of_transformed_samples(self, index_array)
#     799 x = self.x[j]
#     800 params = self.image_data_generator.get_random_transform(x.shape)
# --> 801 x = self.image_data_generator.apply_transform(
#     802     x.astype(self.dtype), params
#     803 )
#     804 x = self.image_data_generator.standardize(x)
#     805 batch_x[i] = x
#
# File ~/.local/lib/python3.10/site-packages/keras/src/preprocessing/image.py:2012, in ImageDataGenerator.apply_transform(self, x, transform_parameters)
#    2009 img_col_axis = self.col_axis - 1
#    2010 img_channel_axis = self.channel_axis - 1
# -> 2012 x = apply_affine_transform(
#    2013     x,
#    2014     transform_parameters.get("theta", 0),
#    2015     transform_parameters.get("tx", 0),
#    2016     transform_parameters.get("ty", 0),
#    2017     transform_parameters.get("shear", 0),
#    2018     transform_parameters.get("zx", 1),
#    2019     transform_parameters.get("zy", 1),
#    2020     row_axis=img_row_axis,
#    2021     col_axis=img_col_axis,
#    2022     channel_axis=img_channel_axis,
#    2023     fill_mode=self.fill_mode,
#    2024     cval=self.cval,
#    2025     order=self.interpolation_order,
#    2026 )
#    2028 if transform_parameters.get("channel_shift_intensity") is not None:
#    2029     x = apply_channel_shift(
#    2030         x,
#    2031         transform_parameters["channel_shift_intensity"],
#    2032         img_channel_axis,
#    2033     )
#
# File ~/.local/lib/python3.10/site-packages/keras/src/preprocessing/image.py:2532, in apply_affine_transform(x, theta, tx, ty, shear, zx, zy, row_axis, col_axis, channel_axis, fill_mode, cval, order)
#    2527     raise ImportError("Image transformations require SciPy. Install SciPy.")
#    2529 # Input sanity checks:
#    2530 # 1. x must 2D image with one or more channels (i.e., a 3D tensor)
#    2531 # 2. channels must be either first or last dimension
# -> 2532 if np.unique([row_axis, col_axis, channel_axis]).size != 3:
#    2533     raise ValueError(
#    2534         "'row_axis', 'col_axis', and 'channel_axis' must be distinct"
#    2535     )
#    2537 # shall we support negative indices?
#
# File ~/.local/lib/python3.10/site-packages/numpy/lib/arraysetops.py:274, in unique(ar, return_index, return_inverse, return_counts, axis, equal_nan)
#     272 ar = np.asanyarray(ar)
#     273 if axis is None:
# --> 274     ret = _unique1d(ar, return_index, return_inverse, return_counts,
#     275                     equal_nan=equal_nan)
#     276     return _unpack_tuple(ret)
#     278 # axis was specified and not None
#
# File ~/.local/lib/python3.10/site-packages/numpy/lib/arraysetops.py:328, in _unique1d(ar, return_index, return_inverse, return_counts, equal_nan)
#     323 def _unique1d(ar, return_index=False, return_inverse=False,
#     324               return_counts=False, *, equal_nan=True):
#     325     """
#     326     Find the unique elements of an array, ignoring shape.
#     327     """
# --> 328     ar = np.asanyarray(ar).flatten()
#     330     optional_indices = return_index or return_inverse
#     332     if optional_indices:
#
# KeyboardInterrupt:
